# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Housing.csv")
print(data)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
print("Mean price = ", data['price'].mean())
print("Mean bedrooms = ", data['parking'].mean())
# Out:
# Mean price =  4766729.247706422
# Mean bedrooms =  0.6935779816513762

# %%
data.describe(include='all')
# Out:
#                price          area    bedrooms   bathrooms     stories  \
# count   5.450000e+02    545.000000  545.000000  545.000000  545.000000
# unique           NaN           NaN         NaN         NaN         NaN
# top              NaN           NaN         NaN         NaN         NaN
# freq             NaN           NaN         NaN         NaN         NaN
# mean    4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std     1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min     1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%     3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%     4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%     5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max     1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#        mainroad guestroom basement hotwaterheating airconditioning  \
# ...

# %%
data['area'].describe()
# Out:
# count      545.000000
# mean      5150.541284
# std       2170.141023
# min       1650.000000
# 25%       3600.000000
# 50%       4600.000000
# 75%       6360.000000
# max      16200.000000
# Name: area, dtype: float64

# %%
data.shape
# Out:
# (545, 13)

# %%
len(data)
# Out:
# 545

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 13

# %%
data.size
# Out:
# 7085

# %%
plt.figure(figsize=(3,3))
plt.hist(data['price'], bins=20)
plt.xlabel("Price")
plt.ylabel("Count")
plt.tight_layout()



#plt.savefig("price_hist.png")

# %%
plt.figure(figsize=(3,3))
plt.hist(data['area'], bins=20)
# Out:
# (array([ 20.,  53., 105.,  93.,  47.,  70.,  56.,  32.,  23.,  16.,   8.,
#           7.,   4.,   4.,   1.,   4.,   0.,   0.,   0.,   2.]),
#  array([ 1650. ,  2377.5,  3105. ,  3832.5,  4560. ,  5287.5,  6015. ,
#          6742.5,  7470. ,  8197.5,  8925. ,  9652.5, 10380. , 11107.5,
#         11835. , 12562.5, 13290. , 14017.5, 14745. , 15472.5, 16200. ]),
#  <BarContainer object of 20 artists>)

# %%
plt.figure(figsize=(5,5))
plt.scatter(data['price'], data['area'])

# %%
plt.boxplot(data['area'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1355d37d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x135402d80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x135402180>],
#  'medians': [<matplotlib.lines.Line2D at 0x135403320>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1354034a0>],
#  'means': []}

# %%
plt.violinplot(data['area'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1355acf80>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1355add30>,
#  'cmins': <matplotlib.collections.LineCollection at 0x135596c30>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1353898e0>}

# %%
plt.plot(data['price'], data['area'])

# %%
df = pd.read_csv('DailyDelhiClimateData.csv')

# %%
df.describe(include='all')
# Out:
#               date    meantemp    humidity  wind_speed  meanpressure
# count          114  114.000000  114.000000  114.000000    114.000000
# unique         114         NaN         NaN         NaN           NaN
# top     2017-01-01         NaN         NaN         NaN           NaN
# freq             1         NaN         NaN         NaN           NaN
# mean           NaN   21.713079   56.258362    8.143924   1004.035090
# std            NaN    6.360072   19.068083    3.588049     89.474692
# min            NaN   11.000000   17.750000    1.387500     59.000000
# 25%            NaN   16.437198   39.625000    5.563542   1007.437500
# 50%            NaN   19.875000   57.750000    8.069444   1012.739316
# 75%            NaN   27.705357   71.902778   10.068750   1016.739583
# max            NaN   34.500000   95.833333   19.314286   1022.809524

# %%
plt.plot(df['date'], df['meantemp'])

# %%
plt.scatter(df['meantemp'], df['humidity'])

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
type(df['date'])
# Out:
# pandas.core.series.Series

# %%
plt.plot(df['date'], df['meantemp'])
